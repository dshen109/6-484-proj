# %%
# !pip install git+https://github.com/taochenshh/easyrl.git > /dev/null 2>&1
# !pip install git+https://github.com/dshen109/rc-building-sim.git
# !pip install git+https://github.com/dshen109/6-484-proj.git@daniel
# Out:
# Collecting git+https://github.com/dshen109/6-484-proj.git@daniel
#   Cloning https://github.com/dshen109/6-484-proj.git (to revision daniel) to /tmp/pip-req-build-ar90xdfu
#   Running command git clone --filter=blob:none --quiet https://github.com/dshen109/6-484-proj.git /tmp/pip-req-build-ar90xdfu
#   Running command git checkout -b daniel --track origin/daniel
#   Switched to a new branch 'daniel'
#   Branch 'daniel' set up to track remote branch 'daniel' from 'origin'.
#   Resolved https://github.com/dshen109/6-484-proj.git to commit 4ebfa4d80e34582f8e93eb522384562fd6269ce2
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from deep-hvac==0.0.0) (0.23.1)
# Requirement already satisfied: openpyxl in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from deep-hvac==0.0.0) (3.0.9)
# Requirement already satisfied: pandas in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from deep-hvac==0.0.0) (1.4.1)
# Requirement already satisfied: pysolar in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from deep-hvac==0.0.0) (0.10)
# Requirement already satisfied: tensorboard in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from deep-hvac==0.0.0) (2.8.0)
# Requirement already satisfied: torch in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from deep-hvac==0.0.0) (1.11.0)
# Requirement already satisfied: numpy>=1.18.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from gym->deep-hvac==0.0.0) (1.22.3)
# Requirement already satisfied: importlib-metadata>=4.10.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from gym->deep-hvac==0.0.0) (4.11.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from gym->deep-hvac==0.0.0) (2.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from gym->deep-hvac==0.0.0) (0.0.6)
# Requirement already satisfied: et-xmlfile in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from openpyxl->deep-hvac==0.0.0) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from pandas->deep-hvac==0.0.0) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from pandas->deep-hvac==0.0.0) (2.8.2)
# Requirement already satisfied: setuptools>=41.0.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (60.9.3)
# Requirement already satisfied: grpcio>=1.24.3 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (1.44.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (2.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (2.6.2)
# Requirement already satisfied: wheel>=0.26 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (0.37.1)
# Requirement already satisfied: protobuf>=3.6.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (3.19.4)
# Requirement already satisfied: markdown>=2.6.8 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from tensorboard->deep-hvac==0.0.0) (3.3.6)
# Requirement already satisfied: typing-extensions in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from torch->deep-hvac==0.0.0) (4.1.1)
# Requirement already satisfied: six in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from absl-py>=0.4->tensorboard->deep-hvac==0.0.0) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->deep-hvac==0.0.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->deep-hvac==0.0.0) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->deep-hvac==0.0.0) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->deep-hvac==0.0.0) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from importlib-metadata>=4.10.0->gym->deep-hvac==0.0.0) (3.7.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->deep-hvac==0.0.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->deep-hvac==0.0.0) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->deep-hvac==0.0.0) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard->deep-hvac==0.0.0) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->deep-hvac==0.0.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/oski/.virtualenvs/6484-proj/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->deep-hvac==0.0.0) (3.2.0)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/oski/.virtualenvs/6484-proj/bin/python -m pip install --upgrade pip' command.
# Collecting git+https://github.com/dshen109/rc-building-sim.git@daniel
#   Cloning https://github.com/dshen109/rc-building-sim.git (to revision daniel) to /tmp/pip-req-build-owbmmx3t
#   Running command git clone --filter=blob:none --quiet https://github.com/dshen109/rc-building-sim.git /tmp/pip-req-build-owbmmx3t
#   WARNING: Did not find branch or tag 'daniel', assuming revision or ref.
#   Running command git checkout -q daniel
#   error: pathspec 'daniel' did not match any file(s) known to git
#   error: subprocess-exited-with-error
#
#   × git checkout -q daniel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git checkout -q daniel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/oski/.virtualenvs/6484-proj/bin/python -m pip install --upgrade pip' command.

# %%
from dataclasses import dataclass
import os

from deep_hvac import agent, behavioral_clone, logger, ppo, runner

from easyrl.utils.gym_util import make_vec_env
from easyrl.configs import cfg
import gym
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from torch import nn
from easyrl.utils.torch_util import (
    action_entropy, action_from_dist, action_log_prob, move_to,
    torch_float, torch_to_np
)


@dataclass
class BasicAgent:
    actor: nn.Module
    env: gym.Env

    def __post_init__(self):
        move_to([self.actor],
                device=cfg.alg.device)

    @torch.no_grad()
    def get_action(self, ob, sample=True, *args, **kwargs):
        t_ob = torch_float(ob, device=cfg.alg.device)
        act_dist, _ = self.actor(t_ob)
        # sample from the distribution
        action = action_from_dist(act_dist,
                                  sample=sample)
        # get the log-probability of the sampled actions
        log_prob = action_log_prob(action, act_dist)
        # get the entropy of the action distribution
        entropy = action_entropy(act_dist, log_prob)
        action_info = dict(
            log_prob=torch_to_np(log_prob),
            entropy=torch_to_np(entropy),
        )
        return torch_to_np(action), action_info


def mimic(env_name):
    """Actor that is taught to mimic the expert."""
    agent, _ = ppo.train_ppo(
        env_name=env_name, save_dir='tmp', train=False
    )
    return BasicAgent(agent.actor, env=agent.env)

# %%
os.environ['NSRDB_TRAINING'] = 'https://raw.githubusercontent.com/dshen109/6-484-proj/daniel/data/1704559_29.72_-95.35_2018.csv'
os.environ['ERCOT_TRAINING'] = 'https://raw.githubusercontent.com/dshen109/6-484-proj/daniel/data/houston-2018-prices.pickle'

plot_performace = True
trajectory_file = 'scripts/fixtures/expert-traj-summer.pickle'
trajectory_file = None
n_trajectories = 10

_, env_name = runner.make_default_env(
    terminate_on_discomfort=False, create_expert=False,
    discrete_action=True, season='summer'
)
env = make_vec_env(env_name, 1, 0)
try:
    trajectories = pd.read_pickle(trajectory_file)
    logger.log(f"Loaded expert demonstrations {trajectory_file}")
except FileNotFoundError:
    trajectories = None

expertagent = agent.NaiveAgent(env=env)
behavioral_clone.set_configs(env_name)
if trajectories is None:
    logger.log("Creating demonstration data...")
    trajectories = behavioral_clone.generate_demonstration_data(
        expertagent, env, 20)
    pd.to_pickle(trajectories, trajectory_file)
else:
    trajectories = trajectories
logger.log("Starting behavioral cloning...")
agent_cloned, logs, _ = behavioral_clone.train_bc_agent(
    mimic(env_name), trajectories[:n_trajectories], max_epochs=2000)
torch.save(agent_cloned.actor, 'scripts/output/cloned-agent-summer.pt')

if plot_performace:
    results = runner.get_results(agent_cloned, env.envs[0], time=8*30*24)
    times = results['timestamp'][0]
    t_int = np.array(results['t_inside']).mean(axis=0)
    t_outside = np.array(results['t_outside']).mean(axis=0)
    t_cool_stpt = np.array(results['set_cooling']).mean(axis=0)
    t_heat_stpt = np.array(results['set_heating']).mean(axis=0)
    t_bulk = np.array(results['t_bulk']).mean(axis=0)

    plt.plot(times, t_int, label='t_inside')
    plt.plot(times, t_outside, label='t_outside')
    plt.plot(times, t_bulk, label='t_bulk')
    plt.plot(times, t_cool_stpt, linestyle='dotted', alpha=0.8,
             label='cooling setpoint')
    plt.plot(times, t_heat_stpt, linestyle='dotted', alpha=0.8,
             label='heating setpoint')
    plt.legend()
    plt.show()
